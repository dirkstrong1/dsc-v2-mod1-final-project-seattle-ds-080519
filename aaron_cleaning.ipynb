# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:
#
#
# Name: Aaron Chen (partner: Dirk Van Strong)
# Pace: Full Time
# Scheduled Review Time: 9:30 am, Friday, August 23
# Instructors: Miles, Greg, Cristian, Erin
# Blog Post URL:
#
# You'll clean, explore, and model this dataset with a multivariate linear regression to predict the sale price of houses as accurately as possible.
#
# # Your code here - remember to use markdown cells for comments as well!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
raw_data = pd.read_csv("kc_house_data.csv")
raw_data.head().T
# Out:
#                         0           1           2           3           4
# id             7129300520  6414100192  5631500400  2487200875  1954400510
# date           10/13/2014   12/9/2014   2/25/2015   12/9/2014   2/18/2015
# price              221900      538000      180000      604000      510000
# bedrooms                3           3           2           4           3
# bathrooms               1        2.25           1           3           2
# sqft_living          1180        2570         770        1960        1680
# sqft_lot             5650        7242       10000        5000        8080
# floors                  1           2           1           1           1
# waterfront            NaN           0           0           0           0
# view                    0           0           0           0           0
# condition               3           3           3           5           3
# grade                   7           7           6           7           8
# sqft_above           1180        2170         770        1050        1680
# sqft_basement         0.0       400.0         0.0       910.0         0.0
# yr_built             1955        1951        1933        1965        1987
# yr_renovated            0        1991         NaN           0           0
# zipcode             98178       98125       98028       98136       98074
# lat               47.5112      47.721     47.7379     47.5208     47.6168
# long             -122.257    -122.319    -122.233    -122.393    -122.045
# sqft_living15        1340        1690        2720        1360        1800
# sqft_lot15           5650        7639        8062        5000        7503
